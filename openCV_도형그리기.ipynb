# %% [markdown]
# <a href="https://colab.research.google.com/github/minibe0/python-practice/blob/master/openCV_%EB%8F%84%ED%98%95%EA%B7%B8%EB%A6%AC%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5],[1,4,9,17,25])
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np
#평균 0, 표준편차1인 정규분포도
x=np.random.randn(1000) #표준 정규 분포를 따르는 난수 1,000개를 만든다
y=np.random.randn(1000) 
plt.scatter(x,y)
plt.show()

# %%
# cv2.line(image, start, end, color, thickness): 하나의 직선을 그리는 함수
# start: 시작 좌표(2차원)
# end: 종료 좌표(2차원)
# thickness: 선의 두계
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = np.full((512, 512, 3), 255, np.uint8)
image = cv2.line(image, (0,0),(300,300), (255,0,0), 5 )

plt.imshow(image)
plt. show()

# %%
#cv2.rectangle(image, start, end, color, thickness): 하나의 사각형을 그리는 함수
#start: 시작 좌표(2차원)
#end: 종료 좌표(2차원)
#thickness: 선의 두께 (채우기: -1)

import cv2
import numpy as np
import matplotlib.pyplot as plt

image = np.full((500,500,3), 100, np.uint8)
image = cv2.rectangle(image, (20,20), (255,255), (255,0,0), 5)

plt.imshow(image)
plt.show()

# %%
#cv2.circle(image, center, radian, color, thickness): 하나의 원을 그리는 함수
#center: 원의 중심(2차원)
#radian: 반지름
#thickness: 선의 두께 (채우기: -1)

import cv2
import numpy as np
import matplotlib.pyplot as plt

image=np.full((512,512,3), 255, np.uint8)
image=cv2.circle(image, (255,255), 100, (93,0,0), -1)

plt.imshow(image)
plt.show()

# %%
#cv2.polylines(image, points, is_closed, color, thickness): 하나의 다각형을 그리는 함수

#points: 꼭지점들
#is_closed: 닫힌 도형 여부
#thickness: 선의 두께 (채우기: -1)


import cv2
import numpy as np
import matplotlib.pyplot as plt

image = np.full((512, 512, 3), 255, np.uint8)
points = np.array([[5, 5], [128, 258], [483, 444], [400, 150]])
image = cv2.polylines(image, [points], True, (0, 0, 255), 4)

plt.imshow(image)
plt.show()

# %%
#cv.putText(image, text, position, font_type, font_scale, color): 하나의 텍스트를 그리는 함수
#position: 텍스트가 출력될 위치 
#font_type: 글씨체
#font_scale: 글씨 크기 가중치

import cv2
import numpy as np
import matplotlib.pyplot as plt

image=np.full((820, 820, 3), 255, np.uint8)
image=cv2.putText(image, 'Hello TtoTto', (0,350), cv2.FONT_ITALIC, 4, (255, 0,0))

plt.imshow(image)
plt.show()
