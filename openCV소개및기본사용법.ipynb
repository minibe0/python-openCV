# %% [markdown]
# <a href="https://colab.research.google.com/github/minibe0/python-practice/blob/master/openCV%EC%86%8C%EA%B0%9C%EB%B0%8F%EA%B8%B0%EB%B3%B8%EC%82%AC%EC%9A%A9%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-d5360b04-134c-4800-bf9f-41442eb10e2e" name="files[]" multiple disabled />
#      <output id="result-d5360b04-134c-4800-bf9f-41442eb10e2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pang.jpg to pang.jpg
# ...

# %%
import cv2
image=cv2.imread('pang.jpg')
#  픽셀 수 및 이미지 크기 확인
print(image.shape)
print(image.size)

# 이미지   numpy 객체의 특정 픽셀을 가리킵니다.
# Out:
# (329, 600, 3)
# 592200

# %%
import cv2
import matplotlib.pyplot as plt

img_basic = cv2.imread('pang.jpg', cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_BGR2RGB))
plt.show()

img_basic=cv2.cvtColor(img_basic, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_GRAY2RGB))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img_basic=cv2.imread('pang.jpg')
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_BGR2RGB))
plt.show()
